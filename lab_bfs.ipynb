# %% [markdown]
# <a href="https://colab.research.google.com/github/tapader13/practice-pythin-for-lab-test-/blob/main/lab_bfs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="minhaj"
name
# Out:
# 'minhaj'

# %%
# from collections import deque

visited=set()
# queue=deque()
queue=[]

def bfs(graph,start,visited):


  queue.append(start)
  visited.add(start)

  while queue:
    # vertex=queue.popleft()
    vertex=queue.pop(0)
    print(vertex, end=" ")

    for neighbour in graph[vertex]:
      if neighbour not in visited:
        visited.add(neighbour)
        queue.append(neighbour)



# graph = {
#     '5': ['3', '7'],
#     '3': ['2', '4'],
#     '7': ['8','9'],
#     '2': [],
#     '4': ['8'],
#     '9': [],
#     '8': []
# }

graph = {
    '5': ['3', '7'],
    '3': ['2', '4','5'],
    '7': ['8','9','5'],
    '2': ['3'],
    '4': ['8','3'],
    '9': ['7'],
    '8': ['4','7']
}

bfs(graph,'5',visited)
# Out:
# 5 3 7 2 4 8 9

# %%
# from collections import deque

visited=set()
# queue=deque()
stack=[]

def dfs(graph,start,visited):


  queue.append(start)
  visited.add(start)

  while queue:
    # vertex=queue.popleft()
    vertex=queue.pop(0)
    print(vertex, end=" ")

    for neighbour in graph[vertex]:
      if neighbour not in visited:
        visited.add(neighbour)
        queue.append(neighbour)



# graph = {
#     '5': ['3', '7'],
#     '3': ['2', '4'],
#     '7': ['8','9'],
#     '2': [],
#     '4': ['8'],
#     '9': [],
#     '8': []
# }

graph = {
    '5': ['3', '7'],
    '3': ['2', '4','5'],
    '7': ['8','9','5'],
    '2': ['3'],
    '4': ['8','3'],
    '9': ['7'],
    '8': ['4','7']
}

dfs(graph,'5',visited)

# %%
visited = set()
stack = []

def dfs(graph, start, visited):

    stack.append(start)

    while stack:
        vertex = stack.pop()

        if vertex not in visited:
            print(vertex, end=" ")
            visited.add(vertex)

            for neighbour in graph[vertex]:
                stack.append(neighbour)


graph = {
    '5': ['3', '7'],
    '3': ['2', '4'],
    '7': ['8','9'],
    '2': [],
    '4': ['8'],
    '9': [],
    '8': []
}

dfs(graph,'5',visited)
# Out:
# 5 7 9 8 3 4 2
